# %% [markdown]
# # Импорт и предобработка данных

# %%
import pandas as pd
import numpy as np
from pathlib import Path
from config import RAW_DATA

# Для алгоритмов машинного обучения
from sklearn.ensemble import RandomForestClassifier, GradientBoostingRegressor
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.svm import SVC

# Для предобработки данных
from sklearn.preprocessing import StandardScaler, MinMaxScaler, OneHotEncoder

# Для разделения данных
from sklearn.model_selection import train_test_split, cross_val_score

# Для метрик качества
from sklearn.metrics import accuracy_score, mean_squared_error, classification_report
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[12], line 4
#       2 import numpy as np
#       3 from pathlib import Path
# ----> 4 from config import RAW_DATA
#       6 # Для алгоритмов машинного обучения
#       7 from sklearn.ensemble import RandomForestClassifier, GradientBoostingRegressor
#
# ModuleNotFoundError: No module named 'config'

# %%
full_data = pd.read_csv(RAW_DATA)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 full_data = pd.read_csv(RAW_DATA)
#
# NameError: name 'RAW_DATA' is not defined

# %% [markdown]
# 3фыввфы
